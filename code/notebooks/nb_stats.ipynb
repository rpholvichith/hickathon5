# %% [markdown]
# # Notebook 1

# %%
# Mandatory operation for importing custom libraries
from pathlib import Path
import sys

cwd = Path.cwd()
base = cwd.parent
sys.path.append(str(base))

# %%
# Testing FileManager
from file_manager.file_manager import FileManager

file_manager = FileManager()
print(file_manager.data_folder)
# Out:
# c:\Users\User\Desktop\Hi!ckathon\hickathon5\data

# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
train_data = file_manager.load_training_data()
test_data = file_manager.load_test_data()
tiny_train_data = train_data.iloc[:100000]
# Out:
# c:\Users\User\Desktop\Hi!ckathon\hickathon5\code\file_manager\file_manager.py:40: DtypeWarning: Columns (108,110,111,115,117,118,122,124,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(self.training_data_file, index_col='row_index')
# c:\Users\User\Desktop\Hi!ckathon\hickathon5\code\file_manager\file_manager.py:45: DtypeWarning: Columns (1,5,108,110,111,115,117,118,122,124,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(self.test_data_file, index_col='row_index')

# %% [markdown]
# # Rough look at data

# %%
test_data.head()
# Out:
#           piezo_station_department_code      piezo_station_update_date  \
# row_index
# 2331795                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331796                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331797                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331798                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331799                              01  Sun Jul 14 13:00:02 CEST 2024
#
#            piezo_station_investigation_depth piezo_station_department_name  \
# row_index
# 2331795                                20.00                           Ain
# 2331796                                35.60                           Ain
# 2331797                                35.22                           Ain
# 2331798                                34.20                           Ain
# 2331799                                37.30                           Ain
#
#           piezo_station_commune_code_insee  \
# row_index
# 2331795                              01073
# 2331796                              01363
# 2331797                              01244
# 2331798                              01288
# 2331799                              01422
#
#                                       piezo_station_pe_label  \
# row_index
# 2331795    PIEZOMETRE - MARAIS DE LAVOURS (CEYZERIEU - BR...
# 2331796    PIEZOMETRE - GRAVIERE (ST-JEAN-LE-VIEUX - BRGM...
# 2331797    PIEZOMETRE - BORD AUTOROUTE (MEXIMIEUX - BRGM ...
# 2331798           PIEZOMETRE - GRENY (PERON - BRGM 01) - BSH
# 2331799            FORAGE - ENCLOS (TOSSIAT - BRGM 01) - BSH
#
#           piezo_station_bdlisa_codes  piezo_station_altitude  \
# row_index
# 2331795                  ['712AH37']                  232.00
# 2331796                  ['712GB05']                  247.25
# 2331797                  ['040AJ43']                  218.77
# 2331798       ['516AA00', '516AF00']                  499.85
# 2331799                  ['507AB00']                  260.00
#
#           piezo_station_bss_code piezo_station_commune_name  ...  \
# row_index                                                    ...
# 2331795         07004X0046/D6-20                  Ceyzérieu  ...
# 2331796            06754X0077/F1        Saint-Jean-le-Vieux  ...
# 2331797        06993X0226/MEXI_2                  Meximieux  ...
# 2331798            06533X0070/F2                      Péron  ...
# 2331799            06518X0026/P2                    Tossiat  ...
#
#            prelev_volume_obtention_mode_label_2  prelev_longitude_2  \
# row_index
# 2331795                                     NaN                 NaN
# 2331796                                     NaN                 NaN
# 2331797                                     NaN                 NaN
# 2331798                                     NaN                 NaN
# 2331799                                     NaN                 NaN
#
#           prelev_latitude_2 prelev_commune_code_insee_2  \
# row_index
# 2331795                 NaN                         NaN
# 2331796                 NaN                         NaN
# 2331797                 NaN                         NaN
# 2331798                 NaN                         NaN
# 2331799                 NaN                         NaN
#
#           prelev_other_volume_sum insee_%_agri insee_pop_commune  \
# row_index
# 2331795                       0.0         11.8             992.0
# 2331796                       0.0          0.6            1786.0
# 2331797                       0.0            0            8085.0
# 2331798                       0.0          1.5            2838.0
# 2331799                       0.0          0.2            1352.0
#
#           insee_med_living_level  insee_%_ind insee_%_const
# row_index
# 2331795                    25250          2.9          16.2
# 2331796                    24660         44.5            11
# 2331797                    24890          8.4           7.8
# 2331798                    39700          2.4           5.2
# 2331799                    26180         21.5           9.8
#
# [5 rows x 134 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 611208 entries, 2331795 to 3610822
# Columns: 134 entries, piezo_station_department_code to insee_%_const
# dtypes: float64(90), int64(5), object(39)
# memory usage: 629.5+ MB

# %%
test_data.isna().sum()
# Out:
# piezo_station_department_code            0
# piezo_station_update_date                0
# piezo_station_investigation_depth    38853
# piezo_station_department_name            0
# piezo_station_commune_code_insee         0
#                                      ...
# insee_%_agri                          5692
# insee_pop_commune                     5692
# insee_med_living_level                5692
# insee_%_ind                           5692
# insee_%_const                         5692
# Length: 134, dtype: int64

# %%
test_data.columns
# Out:
# Index(['piezo_station_department_code', 'piezo_station_update_date',
#        'piezo_station_investigation_depth', 'piezo_station_department_name',
#        'piezo_station_commune_code_insee', 'piezo_station_pe_label',
#        'piezo_station_bdlisa_codes', 'piezo_station_altitude',
#        'piezo_station_bss_code', 'piezo_station_commune_name',
#        ...
#        'prelev_volume_obtention_mode_label_2', 'prelev_longitude_2',
#        'prelev_latitude_2', 'prelev_commune_code_insee_2',
#        'prelev_other_volume_sum', 'insee_%_agri', 'insee_pop_commune',
#        'insee_med_living_level', 'insee_%_ind', 'insee_%_const'],
#       dtype='object', length=134)

# %%
# Filter by column key
test_data[test_data.columns[test_data.columns.str.startswith('piezo')]]
# Out:
#           piezo_station_department_code      piezo_station_update_date  \
# row_index
# 2331795                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331796                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331797                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331798                              01  Sun Jul 14 13:00:02 CEST 2024
# 2331799                              01  Sun Jul 14 13:00:02 CEST 2024
# ...                                 ...                            ...
# 3610818                              95  Thu Sep 19 11:45:47 CEST 2024
# 3610819                              95  Thu Sep 19 14:41:55 CEST 2024
# 3610820                              95  Thu Sep 19 14:29:16 CEST 2024
# 3610821                              95   Thu Dec 14 19:02:16 CET 2023
# 3610822                              95   Tue Jan 28 19:01:33 CET 2020
#
#            piezo_station_investigation_depth piezo_station_department_name  \
# row_index
# 2331795                                20.00                           Ain
# 2331796                                35.60                           Ain
# 2331797                                35.22                           Ain
# 2331798                                34.20                           Ain
# 2331799                                37.30                           Ain
# ...                                      ...                           ...
# 3610818                                24.00                    Val-d'Oise
# 3610819                                25.50                    Val-d'Oise
# 3610820                                30.00                    Val-d'Oise
# 3610821                               630.00                    Val-d'Oise
# 3610822                               104.00                    Val-d'Oise
#
#           piezo_station_commune_code_insee  \
# row_index
# 2331795                              01073
# 2331796                              01363
# 2331797                              01244
# 2331798                              01288
# 2331799                              01422
# ...                                    ...
# 3610818                              95119
# 3610819                              95142
# 3610820                              95610
# 3610821                              95313
# 3610822                              95509
#
#                                       piezo_station_pe_label  \
# row_index
# 2331795    PIEZOMETRE - MARAIS DE LAVOURS (CEYZERIEU - BR...
# 2331796    PIEZOMETRE - GRAVIERE (ST-JEAN-LE-VIEUX - BRGM...
# 2331797    PIEZOMETRE - BORD AUTOROUTE (MEXIMIEUX - BRGM ...
# 2331798           PIEZOMETRE - GRENY (PERON - BRGM 01) - BSH
# 2331799            FORAGE - ENCLOS (TOSSIAT - BRGM 01) - BSH
# ...                                                      ...
# 3610818                Puits du hameau de Buchet (Buhy - 95)
# 3610819         PIÉZOMÈTRE DU HAMEAU DE BERCAGNY (CHARS -95)
# 3610820    Piézomètre de la place Roland Vasseur (Théméri...
# 3610821           PIÉZOMÈTRE DE L'ISLE-ADAM (ISLE-ADAM - 95)
# 3610822    Piézomètre de Puiseux-en-France (Puiseux-en-Fr...
#
#           piezo_station_bdlisa_codes  piezo_station_altitude  \
# row_index
# 2331795                  ['712AH37']                  232.00
# 2331796                  ['712GB05']                  247.25
# 2331797                  ['040AJ43']                  218.77
# 2331798       ['516AA00', '516AF00']                  499.85
# 2331799                  ['507AB00']                  260.00
# ...                              ...                     ...
# 3610818                  ['121AZ01']                   63.00
# 3610819                  ['113AQ27']                  103.00
# 3610820                  ['121AP01']                   83.00
# 3610821                  ['127AA99']                   24.00
# 3610822       ['113AQ27', '113AV01']                  131.00
#
#           piezo_station_bss_code piezo_station_commune_name  ...  \
# row_index                                                    ...
# 2331795         07004X0046/D6-20                  Ceyzérieu  ...
# 2331796            06754X0077/F1        Saint-Jean-le-Vieux  ...
# 2331797        06993X0226/MEXI_2                  Meximieux  ...
# 2331798            06533X0070/F2                      Péron  ...
# 2331799            06518X0026/P2                    Tossiat  ...
# ...                          ...                        ...  ...
# 3610818            01258X0020/S1                       Buhy  ...
# 3610819            01266X1013/S1                      Chars  ...
# 3610820        01522X0069/PZ2008               Théméricourt  ...
# 3610821             01531X0047/F                L'Isle-Adam  ...
# 3610822             01534X0049/F          Puiseux-en-France  ...
#
#            piezo_measurement_date  piezo_obtention_mode  \
# row_index
# 2331795                2022-06-01        Valeur mesurée
# 2331796                2022-06-01        Valeur mesurée
# 2331797                2022-06-01        Valeur mesurée
# 2331798                2022-06-01        Valeur mesurée
# 2331799                2022-06-01        Valeur mesurée
# ...                           ...                   ...
# 3610818                2023-09-30        Valeur mesurée
# 3610819                2023-09-30        Valeur mesurée
# 3610820                2023-09-30        Valeur mesurée
# 3610821                2023-09-30        Valeur mesurée
# 3610822                2023-09-30        Valeur mesurée
#
#                         piezo_status piezo_qualification  \
# row_index
# 2331795    Donnée contrôlée niveau 2            Correcte
# 2331796    Donnée contrôlée niveau 2            Correcte
# 2331797    Donnée contrôlée niveau 2            Correcte
# 2331798    Donnée contrôlée niveau 2            Correcte
# 2331799    Donnée contrôlée niveau 2            Correcte
# ...                              ...                 ...
# 3610818    Donnée contrôlée niveau 2            Correcte
# 3610819    Donnée contrôlée niveau 2            Correcte
# 3610820    Donnée contrôlée niveau 2            Correcte
# 3610821    Donnée contrôlée niveau 2            Correcte
# 3610822    Donnée contrôlée niveau 1            Correcte
#
#           piezo_continuity_code         piezo_continuity_name  \
# row_index
# 2331795                     2.0  Point lié au point précédent
# 2331796                     2.0  Point lié au point précédent
# 2331797                     2.0  Point lié au point précédent
# 2331798                     2.0  Point lié au point précédent
# 2331799                     2.0  Point lié au point précédent
# ...                         ...                           ...
# 3610818                     2.0  Point lié au point précédent
# 3610819                     2.0  Point lié au point précédent
# 3610820                     2.0  Point lié au point précédent
# 3610821                     2.0  Point lié au point précédent
# 3610822                     2.0  Point lié au point précédent
#
#           piezo_producer_code  \
# row_index
# 2331795                 196.0
# 2331796                 196.0
# 2331797                 196.0
# 2331798                 196.0
# 2331799                 196.0
# ...                       ...
# 3610818                 238.0
# 3610819                 291.0
# 3610820                 291.0
# 3610821                 238.0
# 3610822                 238.0
#
#                                          piezo_producer_name  \
# row_index
# 2331795        Service Géologique Régional Rhône-Alpes (196)
# 2331796        Service Géologique Régional Rhône-Alpes (196)
# 2331797        Service Géologique Régional Rhône-Alpes (196)
# 2331798        Service Géologique Régional Rhône-Alpes (196)
# 2331799        Service Géologique Régional Rhône-Alpes (196)
# ...                                                      ...
# 3610818      Service Géologique Régional Ile-de-France (238)
# 3610819    Service Géologique Régional Haute-Normandie (291)
# 3610820    Service Géologique Régional Haute-Normandie (291)
# 3610821      Service Géologique Régional Ile-de-France (238)
# 3610822      Service Géologique Régional Ile-de-France (238)
#
#            piezo_measure_nature_code piezo_measure_nature_name
# row_index
# 2331795                            N                   Naturel
# 2331796                            N                   Naturel
# 2331797                            N                   Naturel
# 2331798                            N                   Naturel
# 2331799                            N                   Naturel
# ...                              ...                       ...
# 3610818                            N                   Naturel
# 3610819                            N                   Naturel
# 3610820                            N                   Naturel
# 3610821                            N                   Naturel
# 3610822                            0                  Inconnue
#
# [611208 rows x 24 columns]

# %%
test_data.describe()
# Out:
#        piezo_station_investigation_depth  piezo_station_altitude  \
# count                      572355.000000           611208.000000
# mean                           85.769989              146.468334
# std                           241.824056              190.889950
# min                             0.000000             -999.000000
# 25%                            16.470000               40.000000
# 50%                            38.350000              107.000000
# 75%                            80.000000              185.000000
# max                          5233.400000             2150.000000
#
#        piezo_station_longitude  piezo_station_latitude  piezo_continuity_code  \
# count            611208.000000           611208.000000          611208.000000
# mean                  2.191367               46.382918               1.999084
# std                   2.698975                2.173051               0.030255
# min                  -4.657129               41.399732               1.000000
# 25%                  -0.112823               44.472234               2.000000
# 50%                   1.901276               46.305138               2.000000
# 75%                   4.123897               48.186733               2.000000
# max                   9.519890               50.971087               2.000000
#
#        piezo_producer_code      meteo_id  meteo_latitude  meteo_longitude  \
# count         5.912910e+05  6.112080e+05   611208.000000    611208.000000
# mean          4.994526e+12  3.761418e+07        2.167895        46.388743
# std           1.080798e+13  2.079943e+07        2.657972         2.138046
# min           5.300000e+01  1.027003e+06       -4.771667        42.384667
# 25%           2.650000e+02  2.105600e+07       -0.152000        44.463167
# 50%           3.000000e+02  3.421700e+07        1.903167        46.316333
# 75%           1.219000e+03  5.246900e+07        4.155333        48.166333
# max           4.930211e+13  9.558000e+07        8.145500        50.833833
#
#        meteo_altitude  ...  prelev_volume_1  prelev_longitude_1  \
# count   611208.000000  ...     2.307610e+05       230761.000000
# mean       166.120084  ...     7.985101e+07            1.383527
# std        204.786272  ...     7.994060e+08            2.511107
# min          1.000000  ...     0.000000e+00           -4.487265
# 25%         49.000000  ...     7.230280e+05           -0.490099
# 50%        113.000000  ...     1.783895e+06            0.689252
# 75%        207.000000  ...     4.526111e+06            2.755148
# max       2471.000000  ...     1.524792e+10            8.087510
#
#        prelev_latitude_1  prelev_commune_code_insee_1  prelev_volume_2  \
# count      230761.000000                230761.000000     2.299080e+05
# mean           46.808819                 46331.626072     1.501822e+07
# std             1.888258                 24179.041443     1.060733e+08
# min            42.901007                  2028.000000     1.359000e+03
# 25%            45.159692                 28012.000000     5.414530e+05
# 50%            47.122300                 45148.000000     1.001008e+06
# 75%            48.396896                 67482.000000     2.377701e+06
# max            50.086783                 94054.000000     2.734220e+09
#
#        prelev_longitude_2  prelev_latitude_2  prelev_commune_code_insee_2  \
# count       229908.000000      229908.000000                229908.000000
# mean             1.371783          46.810647                 45701.963355
# std              2.507037           1.886456                 24264.682901
# min             -4.731051          42.869005                  2031.000000
# 25%             -0.456563          45.133697                 27285.000000
# 50%              0.755854          47.087967                 44025.000000
# 75%              2.706590          48.400214                 67281.000000
# max              8.097536          50.086783                 95052.000000
#
#        prelev_other_volume_sum  insee_pop_commune
# count             3.086080e+05      605516.000000
# mean              2.865224e+07        6824.070254
# std               1.086616e+08       32153.037863
# min               0.000000e+00           6.000000
# 25%               0.000000e+00         479.000000
# 50%               1.059127e+07        1223.000000
# 75%               2.578795e+07        3710.000000
# max               2.680132e+09      873076.000000
#
# [8 rows x 95 columns]

# %%
test_data.columns.str.startswith('piezo')
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
train_data['piezo_groundwater_level_category']
# Out:
# row_index
# 0               High
# 1          Very High
# 2               High
# 3          Very High
# 4           Very Low
#              ...
# 3294080     Very Low
# 3294081     Very Low
# 3294082          Low
# 3294083         High
# 3294084      Average
# Name: piezo_groundwater_level_category, Length: 2830316, dtype: object

# %% [markdown]
# # Split raw data by variable category (piezo, weather, ...)
#
# We are only interested in training data.

# %%
from pandas import DataFrame

# Function to extract variable category
def extract_category(
        df: DataFrame,
        category: str,
) -> DataFrame:
    return df[df.columns[df.columns.str.startswith(category)]]

# %%
tiny_train_data = train_data.iloc[:100000]
tiny_train_data.head()
# Out:
#           piezo_station_department_code      piezo_station_update_date  \
# row_index
# 0                                    01  Sun Jul 14 13:00:02 CEST 2024
# 1                                    01  Sun Jul 14 13:00:02 CEST 2024
# 2                                    01  Sun Jul 14 13:00:02 CEST 2024
# 3                                    01  Sun Jul 14 13:00:02 CEST 2024
# 4                                    01  Sun Jul 14 13:00:02 CEST 2024
#
#            piezo_station_investigation_depth piezo_station_department_name  \
# row_index
# 0                                      20.00                           Ain
# 1                                      35.60                           Ain
# 2                                      35.22                           Ain
# 3                                      34.20                           Ain
# 4                                      37.30                           Ain
#
#           piezo_station_commune_code_insee  \
# row_index
# 0                                    01073
# 1                                    01363
# 2                                    01244
# 3                                    01288
# 4                                    01422
#
#                                       piezo_station_pe_label  \
# row_index
# 0          PIEZOMETRE - MARAIS DE LAVOURS (CEYZERIEU - BR...
# 1          PIEZOMETRE - GRAVIERE (ST-JEAN-LE-VIEUX - BRGM...
# 2          PIEZOMETRE - BORD AUTOROUTE (MEXIMIEUX - BRGM ...
# 3                 PIEZOMETRE - GRENY (PERON - BRGM 01) - BSH
# 4                  FORAGE - ENCLOS (TOSSIAT - BRGM 01) - BSH
#
#           piezo_station_bdlisa_codes  piezo_station_altitude  \
# row_index
# 0                        ['712AH37']                  232.00
# 1                        ['712GB05']                  247.25
# 2                        ['040AJ43']                  218.77
# 3             ['516AA00', '516AF00']                  499.85
# 4                        ['507AB00']                  260.00
#
#           piezo_station_bss_code piezo_station_commune_name  ...  \
# row_index                                                    ...
# 0               07004X0046/D6-20                  Ceyzérieu  ...
# 1                  06754X0077/F1        Saint-Jean-le-Vieux  ...
# 2              06993X0226/MEXI_2                  Meximieux  ...
# 3                  06533X0070/F2                      Péron  ...
# 4                  06518X0026/P2                    Tossiat  ...
#
#            prelev_longitude_2  prelev_latitude_2 prelev_commune_code_insee_2  \
# row_index
# 0                    5.698947          45.725106                      1454.0
# 1                    5.464933          46.210734                      1051.0
# 2                    5.085060          45.812828                     69266.0
# 3                    5.802841          46.366049                     39286.0
# 4                    5.377265          46.080989                      1273.0
#
#           prelev_other_volume_sum insee_%_agri insee_pop_commune  \
# row_index
# 0                    1.793055e+09         11.8             992.0
# 1                    1.085125e+09          0.6            1786.0
# 2                    3.810492e+08            0            8085.0
# 3                    3.800911e+08          1.5            2838.0
# 4                    1.966631e+07          0.2            1352.0
#
#           insee_med_living_level insee_%_ind  insee_%_const  \
# row_index
# 0                          25250         2.9           16.2
# 1                          24660        44.5             11
# 2                          24890         8.4            7.8
# 3                          39700         2.4            5.2
# 4                          26180        21.5            9.8
#
#           piezo_groundwater_level_category
# row_index
# 0                                     High
# 1                                Very High
# 2                                     High
# 3                                Very High
# 4                                 Very Low
#
# [5 rows x 135 columns]

# %%
meteo_variables = extract_category(tiny_train_data, 'meteo')
meteo_variables.head()
# Out:
#            meteo_id      meteo_name  meteo_latitude  meteo_longitude  \
# row_index
# 0           1034004          BELLEY        5.688000        45.769333
# 1           1089001        AMBERIEU        5.329333        45.976500
# 2           1027003      BALAN_AERO        5.106667        45.833000
# 3          39413001        LA PESSE        5.843000        46.302833
# 4           1072001  CEYZERIAT_SAPC        5.287667        46.204333
#
#            meteo_altitude  meteo_date  meteo_rain_height  meteo_DRR  \
# row_index
# 0                     330  2020-01-01                0.2        NaN
# 1                     250  2020-01-01                0.0        0.0
# 2                     196  2020-01-01                NaN        NaN
# 3                    1133  2020-01-01                0.0        NaN
# 4                     260  2020-01-01                0.0        NaN
#
#            meteo_temperature_min  meteo_time_tn  ...  meteo_if_frost  \
# row_index                                        ...
# 0                           -1.6          516.0  ...             NaN
# 1                           -2.2          306.0  ...             NaN
# 2                           -1.4          321.0  ...             NaN
# 3                           -2.3            NaN  ...             NaN
# 4                           -2.1          510.0  ...             NaN
#
#            meteo_if_smoke  meteo_if_mist  meteo_if_lightning  \
# row_index
# 0                     NaN            NaN                 NaN
# 1                     0.0            0.0                 NaN
# 2                     NaN            NaN                 NaN
# 3                     NaN            NaN                 NaN
# 4                     NaN            NaN                 NaN
#
#            meteo_evapotranspiration_Monteith  meteo_evapotranspiration_grid  \
# row_index
# 0                                        NaN                            0.5
# 1                                        0.2                            0.2
# 2                                        NaN                            0.0
# 3                                        1.1                            0.9
# 4                                        NaN                            0.1
#
#            meteo_radiation_UV  meteo_snow_height  meteo_snow_thickness_max  \
# row_index
# 0                         NaN                NaN                       NaN
# 1                         NaN                NaN                       0.0
# 2                         NaN                NaN                       NaN
# 3                         NaN                NaN                       0.0
# 4                         NaN                NaN                       NaN
#
#            meteo_snow_thickness_6h
# row_index
# 0                              NaN
# 1                              0.0
# 2                              NaN
# 3                              0.0
# 4                              NaN
#
# [5 rows x 69 columns]
